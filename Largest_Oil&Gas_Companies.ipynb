# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_oil_and_gas_companies_by_revenue'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest oil and gas companies by revenue - Wikipedia</title>
# ...

# %%
table = soup.find_all('table')
table
# Out:
# [<table class="wikitable sortable">
#  <caption>Revenue in US$ billion
#  </caption>
#  <tbody><tr>
#  <th>Country
#  </th>
#  <th>Company Name
#  </th>
#  <th>2017
#  </th>
#  <th>2018
#  </th>
#  <th>2019
#  </th>
#  <th>2020
#  </th>
#  <th>2021
#  </th>
#  <th>2022
#  </th></tr>
#  <tr>
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/23px-Flag_of_Algeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/35px-Flag_of_Algeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/45px-Flag_of_Algeria.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Algeria" title="Algeria">Algeria</a>
#  </td>
#  <td><a href="/wiki/Sonatrach" title="Sonatrach">Sonatrach</a>
#  </td>
# ...

# %%
Titles = soup.find_all('th')
Titles
# Out:
# [<th>Country
#  </th>,
#  <th>Company Name
#  </th>,
#  <th>2017
#  </th>,
#  <th>2018
#  </th>,
#  <th>2019
#  </th>,
#  <th>2020
#  </th>,
#  <th>2021
#  </th>,
#  <th>2022
#  </th>]

# %%
Table_Titles = [title.text.strip() for title in Titles]
Table_Titles
# Out:
# ['Country', 'Company Name', '2017', '2018', '2019', '2020', '2021', '2022']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = Table_Titles)

df
# Out:
# Empty DataFrame
# Columns: [Country, Company Name, 2017, 2018, 2019, 2020, 2021, 2022]
# Index: []

# %%
column_data = soup.find_all('tr')
column_data
# Out:
# [<tr>
#  <th>Country
#  </th>
#  <th>Company Name
#  </th>
#  <th>2017
#  </th>
#  <th>2018
#  </th>
#  <th>2019
#  </th>
#  <th>2020
#  </th>
#  <th>2021
#  </th>
#  <th>2022
#  </th></tr>,
#  <tr>
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/23px-Flag_of_Algeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/35px-Flag_of_Algeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/45px-Flag_of_Algeria.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Algeria" title="Algeria">Algeria</a>
#  </td>
#  <td><a href="/wiki/Sonatrach" title="Sonatrach">Sonatrach</a>
#  </td>
#  <td>33.2<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup>
#  </td>
# ...

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#            Country        Company Name            2017            2018  \
# 0          Algeria           Sonatrach         33.2[4]         30.3[5]
# 1           Angola      Sonangol Group      17.6[8][a]     19.5[10][b]
# 2        Argentina                 YPF     15.3[18][f]     16.6[18][g]
# 3        Australia           APA Group   1.9[26][k][l]   1.9[26][m][n]
# 4        Australia       Origin Energy  10.6[36][w][x]  10.9[37][y][z]
# ..             ...                 ...             ...             ...
# 160  United States       Valero Energy       93.0[906]      117.0[907]
# 161  United States  Williams Companies        8.0[911]        8.6[911]
# 162     Uzbekistan       Uzbekneftegaz                    2.6[914][wj]
# 163      Venezuela               PDVSA            [wo]            [wp]
# 164        Vietnam        Petrovietnam       21.3[923]       26.9[923]
#
#                  2019             2020             2021              2022
# ...

# %%
# show all columns and rows

pd.set_option('display.max.columns', 10)
pd.set_option('display.max.rows', 170)
df
# Out:
#                   Country                             Company Name  \
# 0                 Algeria                                Sonatrach
# 1                  Angola                           Sonangol Group
# 2               Argentina                                      YPF
# 3               Australia                                APA Group
# 4               Australia                            Origin Energy
# 5               Australia                                   Santos
# 6               Australia                          Woodside Energy
# 7                 Austria                                OMV Group
# 8              Azerbaijan                                    SOCAR
# 9                 Bahrain                              nogaholding
# 10             Bangladesh         Bangladesh Petroleum Corporation
# 11             Bangladesh                              Petrobangla
# 12                Belarus                             Belneftekhim
# ...

# %%
df.to_csv(r"C:\Users\esraa\Desktop\Python_Projects\Largest_Oil&Gas_Companies\LargestOil&GasCompanies.csv", index = False)
